# %% [markdown]
# # Demo in Python Notebook

# %%
# !python /Users/kittnguyen/Documents/DS201_Finance/src/llms_inference/gemini_models/span_annotation/main.py
# Out:
# Bắt đầu xử lý 1 contexts.
#    Phạm vi gốc: Từ index 0 đến 0.
# ---
# Xử lý context thứ 0 / 0 (Relative index: 0 / 0)
# Thử model gemini-2.5-flash cho context thứ 0
# Đã lưu kết quả vào file /Users/kittnguyen/Documents/DS201_Finance/data/labeling_data/0.json với model gemini-2.5-flash
# ---
# Hoàn thành xử lý phạm vi đã chọn.
