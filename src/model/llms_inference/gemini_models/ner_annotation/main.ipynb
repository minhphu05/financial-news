# %% [markdown]
# # Demo in Python Notebook

# %%
# !python /Users/kittnguyen/Documents/DS201_Finance/src/llms_inference/gemini_models/ner_annotation/main.py
# Out:
# 📊 Dữ liệu gốc: 62391 câu.
# 🎯 Phạm vi xử lý yêu cầu: Index 0 -> 2
# 📝 Số lượng câu thực tế cần chạy (đã trừ cái cũ): 2
# 📦 Tổng số Batch: 1 (Kích thước: 50)
# --------------------------------------------------
#
# 🚀 Processing Batch 1/1 (IDs: 0 -> 1)
#    ➤ Gửi Batch 1 (Lần 1) tới gemini-2.5-flash...
#    ✅ Batch 1 thành công: 2 items.
#    💾 Đã lưu 2 dòng.
#    💤 Nghỉ 15s...
#
# 🏁 HOÀN THÀNH QUÁ TRÌNH XỬ LÝ.
